# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 数据
N_values = [524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912]
original_GB_sec = [565.429041, 385.563184, 257.840462, 181.476740, 139.742407, 117.398339, 105.965753, 109.673003, 114.791873, 117.651475, 118.415231]
multi_step_GB_sec = [627.272842, 484.587608, 450.669868, 391.580796, 366.110213, 347.638186, 459.105017, 454.080139, 457.888604, 452.900831, 451.537159]

# 创建图表
plt.figure(figsize=(10, 6))

# 绘制数据
plt.plot(N_values, original_GB_sec, marker='o', linestyle='-', color='b', label='Original Histogram')
plt.plot(N_values, multi_step_GB_sec, marker='x', linestyle='--', color='r', label='Multi-Step Histogram')

# 添加标题和标签
plt.title('Performance Comparison of Two GPU Implementations')
plt.xlabel('N (Size of the array)')
plt.ylabel('Performance (GB/sec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()

# 显示图表
plt.show()

# %%
# 数据
N_values = [524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912]
original_time = [142, 230, 409, 766, 1475, 2899, 5745, 10446, 19334, 37117, 73148] # 假设这是你的数据
multi_step_time = [128, 183, 234, 355, 563, 979, 1326, 2523, 4847, 9642, 19183] # 假设这是你的数据

# 创建图表
plt.figure(figsize=(12, 6))

# 子图1: 绘制GB/秒
plt.subplot(1, 2, 1)
original_GB_sec = [565.429041, 385.563184, 257.840462, 181.476740, 139.742407, 117.398339, 105.965753, 109.673003, 114.791873, 117.651475, 118.415231]
multi_step_GB_sec = [627.272842, 484.587608, 450.669868, 391.580796, 366.110213, 347.638186, 459.105017, 454.080139, 457.888604, 452.900831, 451.537159]
plt.plot(N_values, original_GB_sec, marker='o', linestyle='-', color='b', label='Original Histogram')
plt.plot(N_values, multi_step_GB_sec, marker='x', linestyle='--', color='r', label='Multi-Step Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Performance (GB/sec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('Performance Comparison')

# 子图2: 绘制运行时间
plt.subplot(1, 2, 2)
plt.plot(N_values, original_time, marker='o', linestyle='-', color='b', label='Original Histogram')
plt.plot(N_values, multi_step_time, marker='x', linestyle='--', color='r', label='Multi-Step Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Running Time (microsec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('Running Time Comparison')

# 调整子图间的距离
plt.tight_layout(pad=4)

# 显示图表
plt.show()

# %%
# 数据
N_values = [524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912]

# GPU 数据
gpu_original_time = [142, 230, 409, 766, 1475, 2899, 5745, 10446, 19334, 37117, 73148]
gpu_multi_step_time = [128, 183, 234, 355, 563, 979, 1326, 2523, 4847, 9642, 19183]
gpu_original_GB_sec = [565.429041, 385.563184, 257.840462, 181.476740, 139.742407, 117.398339, 105.965753, 109.673003, 114.791873, 117.651475, 118.415231]
gpu_multi_step_GB_sec = [627.272842, 484.587608, 450.669868, 391.580796, 366.110213, 347.638186, 459.105017, 454.080139, 457.888604, 452.900831, 451.537159]

# CPU 数据
cpu_original_time = [25389, 58993, 69331, 85028, 90970, 107208, 130244, 184446, 293323, 472136, 957019]
cpu_multi_pass_time = [64366, 92408, 133373, 115325, 119559, 143239, 130881, 155883, 309315, 499855, 903424]
cpu_original_GB_sec = [9.062488, 4.042448, 3.560669, 3.100648, 3.266971, 3.398116, 3.827608, 4.158173, 4.445029, 5.035776, 4.728281]
cpu_multi_pass_GB_sec = [3.574675, 2.580687, 1.850935, 2.286078, 2.485772, 2.543338, 3.808979, 4.920090, 4.215215, 4.756522, 5.008783]

plt.figure(figsize=(14, 6))

# 子图1: 绘制GB/秒
plt.subplot(1, 2, 1)
plt.plot(N_values, gpu_original_GB_sec, marker='o', linestyle='-', color='b', label='GPU Original Histogram')
plt.plot(N_values, gpu_multi_step_GB_sec, marker='x', linestyle='--', color='b', label='GPU Multi-Step Histogram')
plt.plot(N_values, cpu_original_GB_sec, marker='o', linestyle='-', color='r', label='CPU Original Histogram')
plt.plot(N_values, cpu_multi_pass_GB_sec, marker='x', linestyle='--', color='r', label='CPU Multi-Pass Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Performance (GB/sec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('Performance Comparison')

# 子图2: 绘制运行时间
plt.subplot(1, 2, 2)
plt.plot(N_values, gpu_original_time, marker='o', linestyle='-', color='b', label='GPU Original Histogram')
plt.plot(N_values, gpu_multi_step_time, marker='x', linestyle='--', color='b', label='GPU Multi-Step Histogram')
plt.plot(N_values, cpu_original_time, marker='o', linestyle='-', color='r', label='CPU Original Histogram')
plt.plot(N_values, cpu_multi_pass_time, marker='x', linestyle='--', color='r', label='CPU Multi-Pass Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Running Time (microsec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('Running Time Comparison')

# 调整子图间的距离
plt.tight_layout(pad=4)

# 显示图表
plt.show()

# %%
# 数据
N_values = [524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912]

# GPU 数据
gpu_original_time = [142, 230, 409, 766, 1475, 2899, 5745, 10446, 19334, 37117, 73148]
gpu_multi_step_time = [128, 183, 234, 355, 563, 979, 1326, 2523, 4847, 9642, 19183]
gpu_original_GB_sec = [565.429041, 385.563184, 257.840462, 181.476740, 139.742407, 117.398339, 105.965753, 109.673003, 114.791873, 117.651475, 118.415231]
gpu_multi_step_GB_sec = [627.272842, 484.587608, 450.669868, 391.580796, 366.110213, 347.638186, 459.105017, 454.080139, 457.888604, 452.900831, 451.537159]

# CPU 数据
cpu_original_time = [25389, 58993, 69331, 85028, 90970, 107208, 130244, 184446, 293323, 472136, 957019]
cpu_multi_pass_time = [64366, 92408, 133373, 115325, 119559, 143239, 130881, 155883, 309315, 499855, 903424]
cpu_original_GB_sec = [9.062488, 4.042448, 3.560669, 3.100648, 3.266971, 3.398116, 3.827608, 4.158173, 4.445029, 5.035776, 4.728281]
cpu_multi_pass_GB_sec = [3.574675, 2.580687, 1.850935, 2.286078, 2.485772, 2.543338, 3.808979, 4.920090, 4.215215, 4.756522, 5.008783]

# GPU 图表
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(N_values, gpu_original_GB_sec, marker='o', linestyle='-', color='b', label='Original Histogram')
plt.plot(N_values, gpu_multi_step_GB_sec, marker='x', linestyle='--', color='b', label='Multi-Step Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Performance (GB/sec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('GPU Performance Comparison')

plt.subplot(1, 2, 2)
plt.plot(N_values, gpu_original_time, marker='o', linestyle='-', color='b', label='Original Histogram')
plt.plot(N_values, gpu_multi_step_time, marker='x', linestyle='--', color='b', label='Multi-Step Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Running Time (microsec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('GPU Running Time Comparison')

plt.tight_layout(pad=4)
plt.show()

# CPU 图表
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(N_values, cpu_original_GB_sec, marker='o', linestyle='-', color='r', label='Original Histogram')
plt.plot(N_values, cpu_multi_pass_GB_sec, marker='x', linestyle='--', color='r', label='Multi-Pass Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Performance (GB/sec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('CPU Performance Comparison')

plt.subplot(1, 2, 2)
plt.plot(N_values, cpu_original_time, marker='o', linestyle='-', color='r', label='Original Histogram')
plt.plot(N_values, cpu_multi_pass_time, marker='x', linestyle='--', color='r', label='Multi-Pass Histogram')
plt.xlabel('N (Size of the array)')
plt.ylabel('Running Time (microsec)')
plt.xscale('log')
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.legend()
plt.title('CPU Running Time Comparison')

plt.tight_layout(pad=4)
plt.show()
